# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('stud.csv')
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['test_preparation_course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
fig, axes=plt.subplots(5, 1, figsize=(24, 20))
sns.countplot(x=data['math_score'], hue=data['parental_level_of_education'], ax=axes[0])
axes[0].set_title("math_score vs parental_level_of_education")

sns.countplot(x=data['math_score'], hue=data['gender'], ax=axes[1])
axes[1].set_title("math_score vs gender")

sns.countplot(x=data['math_score'], hue=data['race_ethnicity'], ax=axes[2])
axes[2].set_title("math_score vs race_ethnicity")

sns.countplot(x=data['math_score'], hue=data['lunch'], ax=axes[3])
axes[3].set_title("math_score vs lunch")

sns.countplot(x=data['math_score'], hue=data['test_preparation_course'], ax=axes[3])
axes[4].set_title("math_score vs test_preparation_course")
# Out:
# Text(0.5, 1.0, 'math_score vs test_preparation_course')

# %%
fig, axes=plt.subplots(5, 1, figsize=(24, 20))
sns.countplot(x=data['reading_score'], hue=data['parental_level_of_education'], ax=axes[0])
axes[0].set_title("reading_score vs parental_level_of_education")

sns.countplot(x=data['reading_score'], hue=data['gender'], ax=axes[1])
axes[1].set_title("reading_score vs gender")

sns.countplot(x=data['reading_score'], hue=data['race_ethnicity'], ax=axes[2])
axes[2].set_title("reading_score vs race_ethnicity")

sns.countplot(x=data['reading_score'], hue=data['lunch'], ax=axes[3])
axes[3].set_title("reading_score vs lunch")

sns.countplot(x=data['reading_score'], hue=data['test_preparation_course'], ax=axes[4])
axes[4].set_title("reading_score vs test_preparation_course")
# Out:
# Text(0.5, 1.0, 'reading_score vs test_preparation_course')

# %%
fig, axes=plt.subplots(5, 1, figsize=(24, 20))
sns.countplot(x=data['writing_score'], hue=data['parental_level_of_education'], ax=axes[0])
axes[0].set_title("writing_score vs parental_level_of_education")

sns.countplot(x=data['writing_score'], hue=data['gender'], ax=axes[1])
axes[1].set_title("writing_score vs gender")

sns.countplot(x=data['writing_score'], hue=data['race_ethnicity'], ax=axes[2])
axes[2].set_title("writing_score vs race_ethnicity")

sns.countplot(x=data['writing_score'], hue=data['lunch'], ax=axes[3])
axes[3].set_title("writing_score vs lunch")

sns.countplot(x=data['writing_score'], hue=data['test_preparation_course'], ax=axes[3])
axes[4].set_title("writing_score vs test_preparation_course")
# Out:
# Text(0.5, 1.0, 'writing_score vs test_preparation_course')

# %%
data['total_marks'] = data['math_score'] + data['reading_score'] + data['writing_score']
data['average_marks'] = data['total_marks'] / 3

# %%
data[data['math_score'] == 100]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
data[data['writing_score'] == 100]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 377  female        group D             master's degree  free/reduced
# 403  female        group D                 high school      standard
# 458  female        group E           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 685  female        group E             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# ...

# %%
data[data['reading_score'] == 100]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 381    male        group C          associate's degree      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 712  female        group D                some college      standard
# 886  female        group E          associate's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# ...

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=data,x='average_marks',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=data[data.gender=='female'],x='average_marks',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=data[data.gender=='male'],x='average_marks',kde=True,hue='lunch')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=data,x='average_marks',kde=True,hue='parental_level_of_education')
plt.subplot(142)
ax =sns.histplot(data=data[data.gender=='male'],x='average_marks',kde=True,hue='parental_level_of_education')
plt.subplot(143)
ax =sns.histplot(data=data[data.gender=='female'],x='average_marks',kde=True,hue='parental_level_of_education')
plt.show()

# %%
data.iloc[:, :8].drop('math_score', axis=1)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  reading_score  writing_score
# 0                      none             72             74
# ...

# %%
X = data.iloc[:, :8].drop('math_score', axis=1)
y = data['math_score']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_features = X.select_dtypes(include='object').columns
numeric_features = X.select_dtypes(exclude='object').columns

ct = ColumnTransformer(
    [
        ("OHE", OneHotEncoder(), categorical_features),
        ("scaling", StandardScaler(), numeric_features)
    ]
)

# %%
X = ct.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# !pip install catboost
# !pip install xgboost

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

# %%
def evaluation(true, predicted):
    mse = mean_squared_error(true, predicted)
    mae = mean_absolute_error(true, predicted)
    r2 = r2_score(true, predicted)
    rmse = np.sqrt(mse)
    return f"mse = {mse}, mae = {mae}, r2 = {r2}, rmse = {rmse}"

# %%
models = {
    "knn":KNeighborsRegressor(),
    "Decision tree":DecisionTreeRegressor(),
    "Random forest": RandomForestRegressor(),
    "svr":SVR(),
    "ridge": Ridge(),
    "linear regression":LinearRegression(),
    "lasso":Lasso(),
    "ada boost": AdaBoostRegressor(),
    "CatBoost":CatBoostRegressor(verbose=False),
    "Xg Boost":XGBRegressor()
}

model_list=[]
r2_list=[]
rmse_list=[]
mae_list=[]
mse_list=[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    mse, mae, r2, rmse = evaluation(y_test, pred)
    model_list.append(list(models.keys())[i])
    r2_list.append(r2)
    rmse_list.append(rmse)
    mae_list.append(mae)
    mse_list.append(mse)
    print(f"model : {list(models.keys())[i]}, mean_squared_error : {mse}, mean absolute error : {mae},r2 score: {r2}, rmse : {rmse}")
    print("\n")
# Out:
# model : knn, mean_squared_error : 56.6472, mean absolute error : 5.8373333333333335,r2 score: 0.7723280481594301, rmse : 7.526433418293156
#
#
# model : Decision tree, mean_squared_error : 65.29, mean absolute error : 6.43,r2 score: 0.7375915890693484, rmse : 8.080222769206305
#
#
# model : Random forest, mean_squared_error : 38.315933685185186, mean absolute error : 4.919044444444443,r2 score: 0.846003625797922, rmse : 6.189986565832368
#
#
# model : svr, mean_squared_error : 67.9632245532446, mean absolute error : 5.728331056674932,r2 score: 0.7268475760952678, rmse : 8.243981110679755
#
#
# model : ridge, mean_squared_error : 30.875711669044243, mean absolute error : 4.415505801902547,r2 score: 0.8759067784434542, rmse : 5.5565917313623325
#
#
# model : linear regression, mean_squared_error : 31.206311848958332, mean absolute error : 4.437604166666667,r2 score: 0.874578056313501, rmse : 5.586260990050351
#
#
# ...

# %% [markdown]
# ###
# 1. Random Forest
# 2. ridge
# 3. linear reggression
# 4. adaboost
# 5. catboost

# %%
eval = pd.DataFrame([model_list, r2_list, rmse_list, mse_list, mae_list], index=['model_list', 'r2_list','rmse_list','mse_list', 'mae_list'])

# %% [markdown]
# ### Hyperparameter Tuning

# %%
rf_params = {'max_depth': [5, 8, 15, None, 10],
 'max_features': [5, 7, 'auto', 8],
 'min_samples_split': [2, 8, 15, 20],
 'n_estimators': [100, 200, 500, 1000]}

# %%
ridge_params = {'alpha':[1.0], 'tol':[0.0001]}

param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'depth': [4, 6, 8],
    'iterations': [100, 500, 1000],
    'l2_leaf_reg': [1, 3, 5, 7, 10],
    'bagging_temperature': [0, 0.5, 1],
    'border_count': [32, 64, 128],
    'random_strength': [1, 2, 5, 10]
}

# %%
adaboost_param = {
    "n_estimators": [50, 100, 200, 500],
    "learning_rate": [0.01, 0.05, 0.1, 0.5, 1.0],
    "loss": ["linear", "square", "exponential"]
}

# %%
randomcv_models = [
    #                ("RF", RandomForestRegressor(), rf_params),
    # ("AB", AdaBoostRegressor(), adaboost_param),
    # ("ridge", Ridge(), ridge_params),
    ("catboost", CatBoostRegressor(), param_grid)
                   
                   ]

# %%
model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 0:	learn: 14.7518614	total: 2.51ms	remaining: 2.51s
# 1:	learn: 14.6593235	total: 6.03ms	remaining: 3.01s
# 2:	learn: 14.5786069	total: 8.16ms	remaining: 2.71s
# 3:	learn: 14.5017124	total: 10.6ms	remaining: 2.64s
# 4:	learn: 14.4071234	total: 12.5ms	remaining: 2.48s
# 5:	learn: 14.3108052	total: 14.4ms	remaining: 2.38s
# 6:	learn: 14.2285671	total: 16.4ms	remaining: 2.32s
# 7:	learn: 14.1595002	total: 18.5ms	remaining: 2.3s
# 8:	learn: 14.0795899	total: 20.5ms	remaining: 2.25s
# 9:	learn: 14.0037635	total: 22.4ms	remaining: 2.22s
# 10:	learn: 13.9458492	total: 24.3ms	remaining: 2.18s
# 11:	learn: 13.8537965	total: 26ms	remaining: 2.14s
# 12:	learn: 13.7872387	total: 27.7ms	remaining: 2.1s
# 13:	learn: 13.6958028	total: 29.6ms	remaining: 2.08s
# 14:	learn: 13.6278287	total: 30.9ms	remaining: 2.03s
# 15:	learn: 13.5576325	total: 32.6ms	remaining: 2s
# 16:	learn: 13.4719206	total: 34.9ms	remaining: 2.02s
# ...

# %%
random.best_estimator_.fit(X_train, y_train)
pred = random.best_estimator_.predict(X_test)
# Out:
# 0:	learn: 14.7518614	total: 2.09ms	remaining: 2.09s
# 1:	learn: 14.6593235	total: 4.9ms	remaining: 2.45s
# 2:	learn: 14.5786069	total: 6.46ms	remaining: 2.15s
# 3:	learn: 14.5017124	total: 9.2ms	remaining: 2.29s
# 4:	learn: 14.4071234	total: 11.9ms	remaining: 2.37s
# 5:	learn: 14.3108052	total: 14.2ms	remaining: 2.36s
# 6:	learn: 14.2285671	total: 16.5ms	remaining: 2.33s
# 7:	learn: 14.1595002	total: 17.9ms	remaining: 2.21s
# 8:	learn: 14.0795899	total: 19.7ms	remaining: 2.17s
# 9:	learn: 14.0037635	total: 21.2ms	remaining: 2.1s
# 10:	learn: 13.9458492	total: 23.6ms	remaining: 2.12s
# 11:	learn: 13.8537965	total: 25.7ms	remaining: 2.12s
# 12:	learn: 13.7872387	total: 27.7ms	remaining: 2.1s
# 13:	learn: 13.6958028	total: 29.1ms	remaining: 2.05s
# 14:	learn: 13.6278287	total: 30.6ms	remaining: 2.01s
# 15:	learn: 13.5576325	total: 32.2ms	remaining: 1.98s
# 16:	learn: 13.4719206	total: 34.7ms	remaining: 2s
# 17:	learn: 13.3892105	total: 37.5ms	remaining: 2.05s
# ...

# %%
evaluation(y_test, pred)
# Out:
# 'mse = 33.04503126025234, mae = 4.499488514037047, r2 = 0.8671880204907869, rmse = 5.748480778453759'

# %%
random.best_estimator_

# %%
random.best_params_
# Out:
# {'random_strength': 2,
#  'learning_rate': 0.01,
#  'l2_leaf_reg': 1,
#  'iterations': 1000,
#  'depth': 4,
#  'border_count': 64,
#  'bagging_temperature': 0}

# %%
best_params = {'random_strength': 2,
 'learning_rate': 0.01,
 'l2_leaf_reg': 1,
 'iterations': 1000,
 'depth': 4,
 'border_count': 64,
 'bagging_temperature': 0}
